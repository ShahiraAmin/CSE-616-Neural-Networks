# %%
#Importing libraries
import pandas as pd
import numpy as np
import random
import os
import cv2
from time import time
import matplotlib.pyplot as plt
from matplotlib.image import imread
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score
np.random.seed(42)

from sklearn.metrics import confusion_matrix
import seaborn as sns

from matplotlib import style
style.use('fivethirtyeight')

# %%
#Import the functions that I defined using python built-in magic command "run".
# %run visualize_classes.ipynb 
# %run traindata_statistics.ipynb
# %run visualize_testdata.ipynb
# %run load_traindata.ipynb
# %run shuffle_data.ipynb
# %run split_data.ipynb
# %run one_hot_encoding.ipynb
# %run configure_network.ipynb
# %run create_model_2.ipynb
# %run train_model.ipynb
# %run load_testdata.ipynb
# %run evaluate.ipynb

# %%
#Define the data directory and call visualize_classes function to print the traffic sign and label for each class
data_dir = '/Users/shahiraamin/Desktop/archive'
classes = visualize_classes(data_dir)

# %%
#Call traindata_statistics function to calculate the number of training images provided in the dataset for each class
traindata_statistics(data_dir)
# Out:
# 39209

# %%
#Visualize 25 random samples from test data
visualize_testdata(data_dir)

# %%
#Define image width, height, and number of channels
IMG_HEIGHT = 30
IMG_WIDTH = 30
channels = 3
#Load the training data
img_data,img_labels = load_traindata(IMG_HEIGHT,IMG_WIDTH,len(classes),data_dir)
#Shuffle the training data
img_data,img_labels = shuffle_data(img_data,img_labels)
# Out:
# (39209, 30, 30, 3) (39209,)
# (39209, 30, 30, 3) (39209,)

# %%
#split the training data into training set and validation set
X_train, X_val, y_train, y_val = split_data(img_data,img_labels)
# Out:
# X_train.shape (27446, 30, 30, 3)
# X_valid.shape (11763, 30, 30, 3)
# y_train.shape (27446,)
# y_valid.shape (11763,)

# %%
#one hot encoding of training labels and validation labels
ytrain = one_hot_encoding(y_train,len(classes))
yval = one_hot_encoding(y_val,len(classes))

ytrain.shape
# Out:
# (27446, 43)

# %%
#Configure the network parameters
lr,opt,epochs,batch_size = configure_network()
print(lr,epochs,batch_size)
# Out:
# 0.001 30 50

# %%
#Create the model
model = create_model_2(IMG_HEIGHT,IMG_WIDTH,channels)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_1 (Conv2D)           (None, 14, 14, 16)        448
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_2 (Dense)             (None, 512)               1606144
#
#  dense_3 (Dense)             (None, 43)                22059
#
# =================================================================
# Total params: 1,628,651
# Trainable params: 1,628,651
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Train the model
train_model(model,X_train,X_val,ytrain,yval,lr,opt,epochs,batch_size)
# Out:
# Epoch 1/30
# 549/549 [==============================] - 14s 25ms/step - loss: 2.1138 - accuracy: 0.4034 - val_loss: 1.1417 - val_accuracy: 0.6501
# Epoch 2/30
# 549/549 [==============================] - 13s 24ms/step - loss: 1.4152 - accuracy: 0.5706 - val_loss: 0.9177 - val_accuracy: 0.7063
# Epoch 3/30
# 549/549 [==============================] - 13s 24ms/step - loss: 1.1875 - accuracy: 0.6322 - val_loss: 0.7321 - val_accuracy: 0.7774
# Epoch 4/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.9857 - accuracy: 0.6940 - val_loss: 0.5906 - val_accuracy: 0.8118
# Epoch 5/30
# 549/549 [==============================] - 15s 27ms/step - loss: 0.8206 - accuracy: 0.7428 - val_loss: 0.4865 - val_accuracy: 0.8528
# Epoch 6/30
# 549/549 [==============================] - 14s 25ms/step - loss: 0.7204 - accuracy: 0.7749 - val_loss: 0.4468 - val_accuracy: 0.8577
# Epoch 7/30
# 549/549 [==============================] - 14s 25ms/step - loss: 0.6260 - accuracy: 0.8066 - val_loss: 0.3858 - val_accuracy: 0.8792
# Epoch 8/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.5604 - accuracy: 0.8276 - val_loss: 0.3079 - val_accuracy: 0.9084
# Epoch 9/30
# 549/549 [==============================] - 13s 23ms/step - loss: 0.4924 - accuracy: 0.8481 - val_loss: 0.2509 - val_accuracy: 0.9294
# Epoch 10/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.4442 - accuracy: 0.8640 - val_loss: 0.2307 - val_accuracy: 0.9356
# Epoch 11/30
# 549/549 [==============================] - 14s 25ms/step - loss: 0.3987 - accuracy: 0.8782 - val_loss: 0.2232 - val_accuracy: 0.9369
# Epoch 12/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.3700 - accuracy: 0.8892 - val_loss: 0.1979 - val_accuracy: 0.9424
# Epoch 13/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.3381 - accuracy: 0.8979 - val_loss: 0.1894 - val_accuracy: 0.9438
# Epoch 14/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.3114 - accuracy: 0.9087 - val_loss: 0.1642 - val_accuracy: 0.9534
# Epoch 15/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.2897 - accuracy: 0.9134 - val_loss: 0.1467 - val_accuracy: 0.9591
# Epoch 16/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.2683 - accuracy: 0.9202 - val_loss: 0.1429 - val_accuracy: 0.9597
# Epoch 17/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.2513 - accuracy: 0.9261 - val_loss: 0.1315 - val_accuracy: 0.9638
# Epoch 18/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.2363 - accuracy: 0.9315 - val_loss: 0.1247 - val_accuracy: 0.9671
# Epoch 19/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.2268 - accuracy: 0.9339 - val_loss: 0.1282 - val_accuracy: 0.9638
# Epoch 20/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.2108 - accuracy: 0.9378 - val_loss: 0.1136 - val_accuracy: 0.9681
# Epoch 21/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.1985 - accuracy: 0.9433 - val_loss: 0.1054 - val_accuracy: 0.9736
# Epoch 22/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.1936 - accuracy: 0.9446 - val_loss: 0.1138 - val_accuracy: 0.9719
# Epoch 23/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.1895 - accuracy: 0.9452 - val_loss: 0.0927 - val_accuracy: 0.9762
# Epoch 24/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.1747 - accuracy: 0.9506 - val_loss: 0.0848 - val_accuracy: 0.9793
# Epoch 25/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.1619 - accuracy: 0.9537 - val_loss: 0.0901 - val_accuracy: 0.9770
# Epoch 26/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.1591 - accuracy: 0.9529 - val_loss: 0.0799 - val_accuracy: 0.9812
# Epoch 27/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.1523 - accuracy: 0.9561 - val_loss: 0.0771 - val_accuracy: 0.9787
# Epoch 28/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.1444 - accuracy: 0.9577 - val_loss: 0.0781 - val_accuracy: 0.9799
# Epoch 29/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.1419 - accuracy: 0.9583 - val_loss: 0.0730 - val_accuracy: 0.9827
# Epoch 30/30
# 549/549 [==============================] - 13s 24ms/step - loss: 0.1351 - accuracy: 0.9605 - val_loss: 0.0639 - val_accuracy: 0.9839
# Train time:  399.4409830570221

# %%
#Load test data
X_test, y_test = load_testdata(IMG_HEIGHT,IMG_WIDTH,data_dir)
# Out:
# (12630, 30, 30, 3) (12630,)

# %%
#Evaluate the trained model on the test data
#This will print the first 25 images in the test data along with their actual and predicated class numbers as x labels
#This will also print the test accuracy (%) and confusion matrix
evaluate(X_test,y_test,model)
# Out:
# Test Data accuracy:  82.28028503562945
